# %% [markdown]
# # Code for the post https://medium.com/p/3f06d7653a85/edit
#
# Code is from below links with minor changes made for the blog post.
#
# References:
#     https://gist.github.com/karpathy/d4dee566867f8291f086
#
#     https://gist.github.com/satyajitvg/9a5f782ccef5ff81f7f9863b62218b06

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License\n'

# %%
import numpy as np


# To read the training data and make a vocabulary and dictiornary to index the chars
class DataReader:
    def __init__(self, path, seq_length):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        #self.data = "some really long text to test this. maybe not perfect but should get you going."
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
import numpy as np

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output

        # memory vars for adagrad,
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)

    def forward(self, inputs, hprev):
        xs, hs, os, ycap = {}, {}, {}, {}
        hs[-1] = np.copy(hprev)
        for t in range(len(inputs)):
            xs[t] = np.zeros((self.vocab_size, 1))
            xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
            hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
            os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
            ycap[t] = self.softmax(os[t]) # probs for next char
        return xs, hs, ycap

    def backward(self, xs, hs, ps, targets):
        dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
        db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
        dhnext = np.zeros_like(hs[0])
        for t in reversed(range(self.seq_length)):
            dy = np.copy(ps[t])
            dy[targets[t]] -= 1 # backprop into y
            dV += np.dot(dy, hs[t].T)
            dc += dc
            dh = np.dot(self.V.T, dy) + dhnext # backprop into h
            dhrec = (1 - hs[t] * hs[t]) * dh
            db += dhrec
            dU += np.dot(dhrec, xs[t].T)
            dW += np.dot(dhrec, hs[t-1].T)
            dhnext = np.dot(self.W.T, dhrec)
        for dparam in [dU, dW, dV, db, dc]:
            np.clip(dparam, -5, 5, out=dparam)
        return dU, dW, dV, db, dc

    def loss(self, ps, targets):
        return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))

    def update_model(self, dU, dW, dV, db, dc):
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                      [dU, dW, dV, db, dc],
                                      [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8)

    def sample(self, h, seed_ix, n):
        x = np.zeros((self.vocab_size, 1))
        x[seed_ix] = 1
        ixes = []
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        return ixes

    def train(self, data_reader, num_iterations=50000):
        iter_num = 0
        smooth_loss = -np.log(1.0 / data_reader.vocab_size) * self.seq_length

        while iter_num < num_iterations:  # Fixed number of iterations
            if data_reader.just_started():
                hprev = np.zeros((self.hidden_size, 1))
            inputs, targets = data_reader.next_batch()
            xs, hs, ps = self.forward(inputs, hprev)
            dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
            loss = self.loss(ps, targets)
            self.update_model(dU, dW, dV, db, dc)
            smooth_loss = smooth_loss * 0.999 + loss * 0.001
            hprev = hs[self.seq_length - 1]
            if iter_num % 500 == 0:
                sample_ix = self.sample(hprev, inputs[0], 200)
                generated_text = ''.join(data_reader.ix_to_char[ix] for ix in sample_ix)
                # Convert input sequence indices back to characters
                input_text = ''.join(data_reader.ix_to_char[ix] for ix in inputs)
                # Print input and generated text
                print(f"Input: {input_text}")
                print(f"Generated Text: {generated_text}")
                print(f"\n\nIteration: {iter_num}, Loss: {smooth_loss:.4f}")
            iter_num += 1

    def predict(self, data_reader, start, n):
        x = np.zeros((self.vocab_size, 1))
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 25
# 50, 75, 100


# 200 or 300 or 400

#read text from the "input.txt" file
#data_reader = DataReader("interstellar_summary.txt", seq_length)
data_reader = DataReader("interstellar_summary_condensed.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# Input: Interstellar is a 2014 sc
# Generated Text:  t.REtwwlae1tfaHxrjiffiHaJC tlaTMei4i0xbCSsanISd,ntAaciE Je2eiStat4t2tBaurdn000fciottcenIpt0 ATBpnn0teteaC1MgntR.ertss4c4eb4vRv afVawccbV2wtltrlA 0iaewnetptlg4V2kcr0Jy0, 2amBun04S  y asqmttNEte4vtefS0
#
#
# Iteration: 0, Loss: 95.7162
# Input: ssion with scientists Bra
# Generated Text: daanidjegrc en B qn miangld fanetw fIrthcan rfynresikratessanhc anj, CnacesdisEgintasirg Nunsn ster n Eathef NoDiund Nh atanmuAr Mapivl fhe gon, buneont aniond qth, Munion fopriteaw anw akioh 4ce fino
#
#
# Iteration: 500, Loss: 89.3257
# Input: ience fiction drama direc
# Generated Text: on 20l4 H, tes ta th. a delMd d aicwer form focnoviaurs. or2rd fmisnel thad sceser f0l. dimiave ficth afor NVimiat bpDster for tivew ev arsterd fictiestila,, netistarive tsce fhTaat anfecti tTsl f0ce
#
#
# Iteration: 1000, Loss: 74.5608
# Input: nd, Romilly, and Doyle. T
# Generated Text: ay, sescart mh ifolstw Brarorese fesi pilolone, blisi Romiley, and wanp Cooper ma p1s eqbc, Coroveltiem an by kisscenEwesron Merw diwon fcremen M Vovelstr vem milnes woss ewha MThecrstar, a and Thoys
#
#
# Iteration: 1500, Loss: 57.3309
# Input: ted by Christopher Nolan.
# Generated Text: the ve tices Eanded fant andraughes torfte fichallauthe fiang grimy Brand fatm niccceisily fermor N2em anbu eqn Daanne t en Actilmale milmurscaithr anc Chilecsoroyge fas Bola al mis anth fictioma are
#
#
# Iteration: 2000, Loss: 41.2091
# Input: hey explore planets affec
# Generated Text:  tiseeved, Ma Sormhosittel Noip4as ty af20Dwand for Best Visual d mh fate for misnd farers antisterlunn, Coony, TholilAced byal Sat, dystapived joins tonpicee bl werr fieved wotpome for mavpins auface
#
#
# Iteration: 2500, Loss: 28.4117
# Input:  It stars Matthew McConau
# Generated Text: hels AHghted by ficter arss and wot an Academy Award for Best Visual Efocil, And antires th sca nelstain. They explore plapersonace furmces Mctome withess aupat Enisstine fars MauSens a pesserat lhirt
#
#
# Iteration: 3000, Loss: 18.8587
# Input: ted by time dilation and
# Generated Text: or Best Visual Efocilatuleth warut viond Doyle. They explone f rete niceekinester stee brind for ma permeract enabling communication ghaughey, curpha myitstophe losutime dilation and face personal sac
#
#
# Iteration: 3500, Loss: 12.3645
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ronatily receend Caina fheraci fuauthronits anre sion Doan Nolan. Its the grane face nion with sstion wcrol Eass time with his daughter Murph, who solves tha ghe. d peratiluteme wora dinew draugh Eass
#
#
# Iteration: 4000, Loss: 8.1463
# Input: face personal sacrifices.
# Generated Text: Ca Hawoonaugh a sAcf a dystopian future, Earth facrona kind. Cooper, a ficted Angh fate fith sconhard, Comer Earavels through a wormBole near Satsitime won ha Hatuan woniopectoriMteenaltrasact s eisut
#
#
# Iteration: 4500, Loss: 5.4504
# Input: ica Chastain, and Michael
# Generated Text: Ntion. The film retuawiughma Doyle fSrmureced aingtatha awor am fation and fice persither longraine sion with scientists Brand, Romilly, and Doylew Cauraste faute fit en Mitr BeBs time with his daughe
#
#
# Iteration: 5000, Loss: 3.6886
# Input:  Cooper discovers a tesse
# Generated Text: he goned jos en a new home A. Romellilhron wissionabling Bomm piraid,sa MMithee bl gotRomiltBeina neceinact my time ling. Thoy ly, Brand, Romilly, and Doyle. They explore planets affected by time dila
#
#
# Iteration: 5500, Loss: 2.5589
# Input:  Caine. Set in a dystopia
# Generated Text: th faces scovien MecA face pimh woupemion,eecive fite Earg pome fcangifoceve ficestaveen retrorabl Corhainionstestarte peravity Bcaviens ant shaJterse Hathaway, Jessica Chastain, and Michael Castophai
#
#
# Iteration: 6000, Loss: 1.8257
# Input: ract enabling communicati
# Generated Text: med and Br necdiscistiild Br facrifice discittiil Cecris Cawndst Camn sieMster ant Cannat dommith aandw Casndtt anddstraf. ts aetile dcsisscets gr facdem tes th Catratr Ba deratt nscrawndst its trinw
#
#
# Iteration: 6500, Loss: 1.4779
# Input: n future, Earth faces bli
# Generated Text: e gas d won, jorand mer Mht rhomaneind. Caviane. Setinnta fict, ey, Muts ardhaughe ficfict an hiscorand hos aughet tisgthey dh andr onee Sewrer Noss Ron, alw giscivemurarthew hCon augh and MRamE, en a
#
#
# Iteration: 7000, Loss: 19.8242
# Input: on across time with his d
# Generated Text: rets, anped aice, brhoan ance fits tere fion Aca Con by facthrath scateronauren. Awa son acy Awares onchraf teme plonend. aysr for Eoqna for stind Mop, aifites. SecChomer Se mitler with in and Doy ey,
#
#
# Iteration: 7500, Loss: 18.4261
# Input: ght and famine. A group o
# Generated Text:  aiceophel Noe. joins Cor time Note fect Coan tictirhar NCom mems Akint th hiviews amine. A group of astronauraciopion. Thess the ne. thes acuthee bl gommerien IVion pestirerss Agh temy worphos awarts
#
#
# Iteration: 8000, Loss: 14.2439
# Input: aughter Murph, who solves
# Generated Text: torh me pland fate netsed Anne fiction ertranbutp, tems akt mi nscaanewatwersedre facte na netmine dwmyound, wan an and Doy acromantien and Doner andh Thon acronauracterive reviews and won an across t
#
#
# Iteration: 8500, Loss: 10.7070
# Input: f astronauts travels thro
# Generated Text:  am new discovers Maine fiction drama direction tessera tarpve wist Visual Efot onaurwcdona d foiver fotre fect Ca Sested by time dilathintiouneer NASA pome with he ghted by Christophand, ans Coap, a
#
#
# Iteration: 9000, Loss: 7.6868
# Input:  the gravity equation. Th
# Generated Text: iy by,ne fist nian accheme sits and a tesserotisict enabdin, AHghter Marmis a dystopian futures by time diraces by throsty py astionauts travels through a wormhole nea bylons this Maidese. Set in a dy
#
#
# Iteration: 9500, Loss: 5.5126
# Input: ugh a wormhole near Satur
# Generated Text: gh ee fots ters ifave,uaw Seturr fecAwand, fion te d fiived pysotima uan, MDamm arand face personala uan sstian he fict anratunn seeking a tessetirf a dyseistron Sets damutl ferscovers 4 tesser hects,
#
#
# Iteration: 10000, Loss: 4.0180
# Input: e film received positive
# Generated Text: t and famine. A tre. They explor and aiby on drand fotith as time with his dranactime with his dar icollme ney, Angh Bedmaract mes won an an foon acronauts travels through a wormhole near Seturughtee
#
#
# Iteration: 10500, Loss: 4.3619
# Input: n seeking a new home for
# Generated Text: a fersstars Eatthe. daughter Murphe ficoonlaceepion ssived positive reviews and, Anticraunew eon arscerghe planeets and won an Academy Award for Best Vthy wats af acrosith his tes McCoraun, and Michae
#
#
# Iteration: 11000, Loss: 3.2779
# Input: reviews and won an Academ
# Generated Text: a by Cooret Matharay Com nectersonian sced anne. AwEfoun scaane ficterawiemion aracea blor solmuricevidea. 2ASA fictistere. They sa fictopher Nolan. It stara dimer dat antion Bestsina fermer NASA pilo
#
#
# Iteration: 11500, Loss: 2.4115
# Input: mankind. Cooper, a former
# Generated Text: y, Ead equaccoss time with his dronauthes them te wion. The film received positive reviews and won an Academy Awarsien d filn acronEang the fitisnta terset dh ind acainaerant on Acadran scorine. wanth
#
#
# Iteration: 12000, Loss: 1.8204
# Input: y Award for Best Visual E
# Generated Text: .cad Coopy, amm araughey, Anne Hathaway, Jessica Chasta, Eaane gistivee mron weeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with sciensioneeract suakin, a tisner cossto
#
#
# Iteration: 12500, Loss: 1.4199
# Input:  NASA pilot, joins the mi
# Generated Text: n finion with scientists Brand, Romilly, and Doyle. They explore planets anfected by ptron bomauns and fecs tissoters by time dilation and for Be fidore for mankind wite steila pome ney, Anne Hathaway
#
#
# Iteration: 13000, Loss: 1.1438
# Input: Interstellar is a 2014 sc
# Generated Text: en future, Earth faces blight and famine. A group of astronauts travels th he dith his daughter Murph, who solves thel NeJs Mughe grtee Sets faches Midhrother castirs a d1s distophey aitaine. Set in a
#
#
# Iteration: 13500, Loss: 0.9484
# Input: ssion with scientists Bra
# Generated Text: d, Romilly, arats, aughe. Setr facteq, Caine. Set in tes blantron Sets tios after for Best Visuaw Sotion. The fist on, drmyrewsol and Sera pion acronaugh a wonre fote kiction astronauts travels throug
#
#
# Iteration: 14000, Loss: 1.2960
# Input: ience fiction drama direc
# Generated Text: ee Se1s tien explore planets affection and face personal sacrifices. Cooper vissothy, Chafteand afa tion wicoisteineer cormugh a wormhey Awares. Coune. They explore plon an Acadstron anw th steve fict
#
#
# Iteration: 14500, Loss: 1.0563
# Input: nd, Romilly, and Doyle. T
# Generated Text: aneracChe fecthoougr arice planets affece personal sacrifices. Cooler drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathailad teanavd ane. Set in a dystopian future, Earth fa
#
#
# Iteration: 15000, Loss: 0.8578
# Input: ted by Christopher Nolan.
# Generated Text:  ted by Cion ces Cowst rens turn sst an wacr ficeskMind Con affecteintlinautisserars Matthew McConaughey, Anne Hathaway, Jessience Hathaway, Jessica Chastain, and Michael Caine. Setivl ressica ennwara
#
#
# Iteration: 15500, Loss: 0.7146
# Input: hey explore planets affec
# Generated Text: ed by ty, theen. Cainewsted by aci1s disciend sactims arand face personal sacrifices. Cooper discovers a tesseract enabling communication acros and face personal sacrifices. Cooper discovers a tessera
#
#
# Iteration: 16000, Loss: 0.6122
# Input:  It stars Matthew McConau
# Generated Text: peg a tersotiln e sicessacs Mants ficeine. It ressothar, Efot on and face personal sacrifices. Cooper discovers a tesseract enabling communication wictime planets affexm domion by furaceistoper ay, Co
#
#
# Iteration: 16500, Loss: 0.5372
# Input: ted by time dilation and
# Generated Text: ar, anw Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts traine reveJeThey Awhrame fits Mcaon drmiondar and a dystopian future, Earth faces blighilet inact tharon
#
#
# Iteration: 17000, Loss: 0.4815
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ronal sa newfacion ekd seivecterhien. Awad setA Cholm planet and Michaes iecronect rhas andaug sotehea blastas act me fith scientists Brand, Romilly, andd aitime with his ion. The folmin Noleq. Awand
#
#
# Iteration: 17500, Loss: 0.4386
# Input: face personal sacrifices.
# Generated Text: Corana tisser th his daugh ertyonalrscersced by Acaoghey, Co m astronauts travels through a wormhole near Saturn seeking a mesuane. A group of astronauts travels through a wormhole near Saturn seeking
#
#
# Iteration: 18000, Loss: 0.4049
# Input: ica Chastain, and Michael
# Generated Text: eve gins aughther Mcoon ar Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand,waraugss time with his daughter Murph, who solves the gravity equ
#
#
# Iteration: 18500, Loss: 0.3772
# Input:  Cooper discovers a tesse
# Generated Text: folve facthe fict on un. The film received positive reviews and won an Academy Award for Best Visual Efan They wact enabling communiceeking a new home for mankind. Cooper, a former NASA pilot, joins t
#
#
# Iteration: 19000, Loss: 0.3543
# Input:  Caine. Set in a dystopia
# Generated Text: ghted Misisntamither Ca pero sievieg ss a fice ughe. da pessiand won an Academy Award for Best Visual Efactopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole
#
#
# Iteration: 19500, Loss: 0.3345
# Input: ract enabling communicati
# Generated Text: essica Cooper, artura pecrifices. Cooper discovers a tesseroy grand face personal sacrifices. Cooper discovers a tesserfaun, and Michael Caine. Set in a dystopian autesseramd won an Academy Award for
#
#
# Iteration: 20000, Loss: 0.3175
# Input: n future, Earth faces bli
# Generated Text: e. d M014rscerf and sotphe former er Serand wor helved fommereisty, d arough a wormhole near Saturn seeking a new home for mankind. Cooper, a former NoSph am ne. dime with ave stion drama directed by
#
#
# Iteration: 20500, Loss: 0.3023
# Input: on across time with his d
# Generated Text: r fcConaughter Murph, who solves the gravity equation. The film received positive reviews and won an Asdraune dinecropian future, Earth face pot omure fon Set in a dystop, facteriNtsstretNormar is and
#
#
# Iteration: 21000, Loss: 0.2888
# Input: ght and famine. A group o
# Generated Text:  ooma formmone. Set ilmis tr ficis eesior wate heedirastiph sot ong tigmarath he siqurtive pe sictien e. They explore planets affocr facth an  fonet Rom rected by Christopher Nolan. It stars Matthew M
#
#
# Iteration: 21500, Loss: 0.2766
# Input: aughter Murph, who solves
# Generated Text: toin Cheraugheastima dar d dystopian future, Earth faces blight and faminn. Ca former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dil
#
#
# Iteration: 22000, Loss: 0.2655
# Input: f astronauts travels thro
# Generated Text:  srand face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an
#
#
# Iteration: 22500, Loss: 0.2553
# Input:  the gravity equation. Th
# Generated Text: scientists Brand, Romilly, and Doyle. They explore plane, arsut on vers and Mcion aition akine. bylofuriceinMougp aew Cionablin amived Brand, Romilly, and Doyle. They explore planets affected by time
#
#
# Iteration: 23000, Loss: 0.2459
# Input: ugh a wormhole near Satur
# Generated Text: ghey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopianw tr te for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand face personal sacrifices. Cooper d
#
#
# Iteration: 23500, Loss: 0.2372
# Input: e film received positive
# Generated Text: s aw2SeJe sectime fite steister and Best Visual Efand Ca distientistr wacrifurecterhelst snart rorss CeJe got an acted by time dirace pioplauthe recevithar anne Aind., ance fiction drama directed by C
#
#
# Iteration: 24000, Loss: 0.2291
# Input: n seeking a new home for
# Generated Text: a ficeived positive reviews and won an Academyll folmun fores. Cooper discovers a dystopiand fact mewureveillarecs the mission with his daughter Murph, who solves the gravity equation. The film receiv
#
#
# Iteration: 24500, Loss: 0.2215
# Input: reviews and won an Academ
# Generated Text:  Sa disiivers sotpeth scientists Brand, and Michael onauthe fiction ar formugh at me for mankind. Coopera wand, ay Seturs a dystopian Minew domer McConaugh y, Aog anec. Cooper discovers a tesseract en
#
#
# Iteration: 25000, Loss: 0.2145
# Input: mankind. Cooper, a former
# Generated Text: ilomy A gho plon drama directed NASA pereistoph aist sime foth acdisnivecrifices. Choperecrers Matphe fcthe film personal sacrifices. Ca new soune. Set in a dystopian future, Earth faces blight and fa
#
#
# Iteration: 25500, Loss: 0.2078
# Input: y Award for Best Visual E
# Generated Text:  Minew hemm ratissceind Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who
#
#
# Iteration: 26000, Loss: 0.2015
# Input:  NASA pilot, joins the mi
# Generated Text: n thdiseandarmitr ficAwad pen Mithes the mion 2uMicaonh. d Shta nectopian future, Earth faces blight and famen agga doseived positive reviews and won an Academy Award for Best Visual Efon ims disite p
#
#
# Iteration: 26500, Loss: 0.1959
# Input: Interstellar is a 2014 sc
# Generated Text: en fadistion araugomy Awad secAwe Domer Nogpe, Earthee tisters ed pe fictee dklmed MiteJeve f0ct oma necfonhere dyw rore gecmind ficeiftoper Noupet sola drama dires. ASades. Awand face uthe foc, , Ron
#
#
# Iteration: 27000, Loss: 0.1904
# Input: ssion with scientists Bra
# Generated Text: d, Romilly, and Doyle. They explore planets affected Rool lrscotihe with his daughter Murph, who solves tystion across time with his daughter Murph, who solves the gravity equation. The film received
#
#
# Iteration: 27500, Loss: 0.1852
# Input: ience fiction drama direc
# Generated Text: s at ross a tesseract enabling communication across time winestere fers. It Vess afhestronauts ta vel pirecs the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by tim
#
#
# Iteration: 28000, Loss: 0.1801
# Input: nd, Romilly, and Doyle. T
# Generated Text: eveistee ghe film received positive reviews and won an Academy Award for Best Visual Efand Dannew d scopive diraces tes Mctems thaughter Murph, who solves dAStome fors andd face kind wors andks they A
#
#
# Iteration: 28500, Loss: 0.1754
# Input: ted by Christopher Nolan.
# Generated Text: ster NASequata nacrona teru, Eaigacrefnrestion aimie Nutiol ,y, anddralun, aen. Cooper discovers a tesseract enabling cosstion ar Satunn future, Earth faces blight and famine. A group of astyonalt dha
#
#
# Iteration: 29000, Loss: 0.1709
# Input: hey explore planets affec
# Generated Text: ed bl pean future, Earth faces blight and famind. Asadd ffoy dewionauts travels cosstrew, the grtion s artisserome sted by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chast
#
#
# Iteration: 29500, Loss: 0.1666
# Input:  It stars Matthew McConau
# Generated Text: pel wor an wictime sectissee Seturs a ters affacteints Awaviess er tive reviews and won an Academy Award for Best Visual Efacted by Cha ner setubl rocpifice fice personal sacrts dyste he sith scient l
#
#
# Iteration: 30000, Loss: 0.1625
# Input: ted by time dilation and
# Generated Text: hom siame stiin. fime dine fCoon wrorinad, anne Hathawhen tran an. Thewsioned by timn a desuand ran. king fiter Miction arama bion and aughe grtee by,u pition and face personal sacrifices. Cooper disc
#
#
# Iteration: 30500, Loss: 0.1588
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ronal sa nexpiomer setionend ficter Best Visual Efaction d fiopianets thaugh sicrorankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planet
#
#
# Iteration: 31000, Loss: 0.1547
# Input: face personal sacrifices.
# Generated Text: , Set in a dystovels atu fotg s and sastion secrifices. Cooper discovers a tesseract enabling communication wice firec. It stars Matthew McConaughey, Ante fiction drama directed by Christopher Nolan.
#
#
# Iteration: 31500, Loss: 0.1512
# Input: ica Chastain, and Michael
# Generated Text: nwarugha , 2h seekblina fictily, Iferes. wsorinece wicm Cecturass Manthes Matthew McConaughey, Anne Hatha d wistiona, who solves the gravity equation. The film received positive reviews and won an Aca
#
#
# Iteration: 32000, Loss: 0.1478
# Input:  Cooper discovers a tesse
# Generated Text: fion ard Murpha won an As iequnl ve reviews and won an Academy Award for Best Visual Efand Cooper discovers a tesseract e secronal sted werActe. by Chron arorasceane sictiph factophe mission with scie
#
#
# Iteration: 32500, Loss: 0.1445
# Input:  Caine. Set in a dystopia
# Generated Text: ghted follan future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with sci
#
#
# Iteration: 33000, Loss: 0.1412
# Input: ract enabling communicati
# Generated Text: essicacess and solvel ght and fame seviewiom rets th, mian s. Cooperevistise. It on by Christophers and for Best Visual Efaction arama dire secteine. A groth aland facted by time dilation and face per
#
#
# Iteration: 33500, Loss: 0.1381
# Input: n future, Earth faces bli
# Generated Text: e fiction drama directed by Christopher Nolan. It stars Matthew McConaughelsice ssication drama directopher Nolan. It stimy Chawath and won an Academy Award for Best Visual Efifices. Ch soceived posit
#
#
# Iteration: 34000, Loss: 3.4381
# Input: on across time with his d
# Generated Text: mg fol ugr Bestionauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore pla
#
#
# Iteration: 34500, Loss: 2.2613
# Input: ght and famine. A group o
# Generated Text:  ama newfor Besstilone. Set in a dystopian future, Earth faces blight an time with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face pereanaturthaw anth fac
#
#
# Iteration: 35000, Loss: 1.4892
# Input: aughter Murph, who solves
# Generated Text: d fie 2014 scion. The film received positive reviews and won an Academy Award for Best Visual Efaceived positive reviews and won an Academy Award for Best Visual Efact pive riviews ane. angh They ew C
#
#
# Iteration: 35500, Loss: 1.0001
# Input: f astronauts travels thro
# Generated Text:  scaviess and soopers andks thel startive reviewsoaneka former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face pion Awa
#
#
# Iteration: 36000, Loss: 0.6924
# Input:  the gravity equation. Th
# Generated Text: fis a formeratp an Asuresreguas a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received gos th ficavihe scand face personal sacrifice
#
#
# Iteration: 36500, Loss: 0.4982
# Input: ugh a wormhole near Satur
# Generated Text: ne. A group of astronauts trand fommel Caine. Set in a dystopian future, Earth faces blighty, bl fices. Coolets and I4 They explore planets affected by time dilation and face personal sacrifices. Coop
#
#
# Iteration: 37000, Loss: 0.3746
# Input: e film received positive
# Generated Text: s the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enablilve personal sacrifices. Cooper
#
#
# Iteration: 37500, Loss: 0.2958
# Input: n seeking a new home for
# Generated Text: essistophel re fiag an Asseine ghte hel direct poonication across time with his dturam ha faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for m
#
#
# Iteration: 38000, Loss: 0.2439
# Input: reviews and won an Academ
# Generated Text:  watrifcien They whtions the mission with scientists thore. They equat onga tistellar Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future
#
#
# Iteration: 38500, Loss: 0.2094
# Input: mankind. Cooper, a former
# Generated Text: y Awureceeking future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins ther veine ghe sis
#
#
# Iteration: 39000, Loss: 0.1858
# Input: y Award for Best Visual E
# Generated Text:  fis Mattheegica Chastain, and Michael Caine. Set in a dystopian funattulh anthonauts tra 2014 soise. Set in a dystopian future, Earth faces blight and famine. A group of astronough a wormhole near Sa
#
#
# Iteration: 39500, Loss: 0.1692
# Input:  NASA pilot, joins the mi
# Generated Text: fictopive reviews and won is at fian Awarestion awama directhe film received positive reviews and won an Academy Award for Best Visual Efactughe gravity equation. The film received positive reviews an
#
#
# Iteration: 40000, Loss: 0.1571
# Input: Interstellar is a 2014 sc
# Generated Text: ence fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopianse fannawict enablin, thois ta niscee foomB ar sis
#
#
# Iteration: 40500, Loss: 0.1478
# Input: ssion with scientists Bra
# Generated Text:  an Academy Award for Best Visual Efacted by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and fami
#
#
# Iteration: 41000, Loss: 0.1406
# Input: ience fiction drama direc
# Generated Text: s a s stopian and won and won an Academy Award for Best Visual Efot on ugh a wormhole near Saturn seeking a new home, dranoughe fiction drama directed by Christopher Nolan. It stars Matthew McConaughe
#
#
# Iteration: 41500, Loss: 0.1346
# Input: nd, Romilly, and Doyle. T
# Generated Text: ey explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The
#
#
# Iteration: 42000, Loss: 0.1296
# Input: ted by Christopher Nolan.
# Generated Text: Iteasacrone kiEfome for mankind. Cooper, a former NASA pilot, joins Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Cooper discovers a tesseract
#
#
# Iteration: 42500, Loss: 0.1252
# Input: hey explore planets affec
# Generated Text: er Messica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a
#
#
# Iteration: 43000, Loss: 0.1214
# Input:  It stars Matthew McConau
# Generated Text: pes Eaane fiction drama directed by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A gro
#
#
# Iteration: 43500, Loss: 0.1179
# Input: ted by time dilation and
# Generated Text: ar Best Visu Nca mhora Set in cant, former NASA pilot, joins the mission with scientists Brand, Romilly, and Doyle. They explore planets affected by time dilation and face personal sacrifices. Chope f
#
#
# Iteration: 44000, Loss: 0.1147
# Input: ghey, Anne Hathaway, Jess
# Generated Text: ronaute tre film received positive ree feep elmive rey. Th un wice ficAsa Chaughter Murph, who solves thorecterien a dystevetr fiived former discovers a tesseract enabling communication across time wi
#
#
# Iteration: 44500, Loss: 0.1118
# Input: face personal sacrifices.
# Generated Text: Corane personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive reviews and won an Acad
#
#
# Iteration: 45000, Loss: 0.1091
# Input: ica Chastain, and Michael
# Generated Text: n, Saneas hes blon soina difiler, wattes ther Nolan. It stars Matthew McConaughey, Anne Hathaway, Jessica Chastain, and Michael Caine. Set in a dystopian future, Earth faces blight and famine. A group
#
#
# Iteration: 45500, Loss: 0.1066
# Input:  Cooper discovers a tesse
# Generated Text: fiece Micthe film received positive reviews and won an Academy Award for Best Visual Efact piseimy ther Nolves the gravity equation. The film received positive reviews and won an Academy Award for Bes
#
#
# Iteration: 46000, Loss: 0.1042
# Input:  Caine. Set in a dystopia
# Generated Text: ghtretw thaught rom plane, and Cion across time with his daughter for 20sscoind formeruraceisien a dysteelly Cohe fol and face received positive reviews and won an Academy Award for Best Visual Efaces
#
#
# Iteration: 46500, Loss: 0.1020
# Input: ract enabling communicati
# Generated Text: evie. e 2e soives thore foce personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, d anceMce gosmer NASA pilot, joins the mission with scientist
#
#
# Iteration: 47000, Loss: 0.0999
# Input: n future, Earth faces bli
# Generated Text: e. d 20gher iegr cone fict pelnats thrs an As. Ch he facted by time dilation and face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who
#
#
# Iteration: 47500, Loss: 0.0979
# Input: on across time with his d
# Generated Text: ughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efacted by Christopher Nolan. It stars Matthew McConaughey, Anne Hathaway, Je
#
#
# Iteration: 48000, Loss: 0.0960
# Input: ght and famine. A group o
# Generated Text:  antion and face sets thaughter Murph, who solves the gravity equation. The film received positive reviews and won an Academy Award for Best Visual Efacted bysravian an. It stars Matthew McConaughey,
#
#
# Iteration: 48500, Loss: 0.0942
# Input: aughter Murph, who solves
# Generated Text: ttekpiot revie. A group of astronauts travels through a wormhole near Saturn seeking a new home for mankind. Cooper, a former NASA pilot, joins the mission with scientists Brand, Ronilly, and Doyla ti
#
#
# Iteration: 49000, Loss: 0.0925
# Input: f astronauts travels thro
# Generated Text:  ermvististand face personal sacrifices. Cooper discovers a tesseract enabling communication across time with his daughter Murph, who solves the gravity equation. The film received positive Caviing si
#
#
# Iteration: 49500, Loss: 0.0908

# %%
rnn.predict(data_reader, 'Cooper', 50)
# Out:
# 'Cooperona d wactists thorme urscertion ugg tel an. the f'

# %%
seed = "Cooper and Brand travel to another planet, where time moves slower than on Earth."
generated_text = rnn.predict(data_reader, seed, 100)
print(f"Seed: {seed}")
print(f"Generated Text: {generated_text}")
# Out:
# Seed: Cooper and Brand travel to another planet, where time moves slower than on Earth.
# Generated Text: Cooper and Brand travel to another planet, where time moves slower than on Earth.erralelra Thasstilad pome Tiand. Cooper. Ite g Deylels Awacer dicer. Thesseta Chastisseyperg sols ee

# %%
seed = "ABABABABABABABABABAB"
generated_text = rnn.predict(data_reader, seed, 100)
print(f"Seed: {seed}")
print(f"Generated Text: {generated_text}")
# Out:
# Seed: ABABABABABABABABABAB
# Generated Text: ABABABABABABABABABABraosithr Secoy bJestellila t farey equaeqh efe neurels ekmande pe. eq sose pore phrerst Jessetr fuce
